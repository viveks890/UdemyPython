# %%
age = 20
print(age)
# Out:
# 20

# %%
prompt = "Enter Age : "
user_age = int(input(prompt))
print(f"Your age is {user_age}")
# Out:
# Your age is 30

# %%
age_comparison = user_age >= age

if age_comparison:
    print("You are older than me")
else:
    print("I am older than you")
# Out:
# You are older than me
